# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px 
import plotly.io as pio 
pio.renderers.default = "svg"

# %%
dataset = pd.read_csv('Zomato_Chennai_Dataset.csv')

# %%
dataset.head()
# Out:
#                                           Zomato URL     Name of Restaurant  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address     Location  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# ...

# %%
dataset.shape
# Out:
# (12032, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
# Zomato URL               12032 non-null object
# Name of Restaurant       12032 non-null object
# Address                  12032 non-null object
# Location                 12032 non-null object
# Cuisine                  12032 non-null object
# Top Dishes               12032 non-null object
# Price for 2              12032 non-null float64
# Dining Rating            12032 non-null object
# Dining Rating Count      12032 non-null object
# Delivery Rating          12032 non-null object
# Delivery Rating Count    12032 non-null object
# Features                 12032 non-null object
# dtypes: float64(1), object(11)
# memory usage: 1.1+ MB

# %%
dataset['Price for 2'] = dataset['Price for 2'].astype('float64')

# %%
dataset.describe()
# Out:
#         Price for 2
# count  12032.000000
# mean     397.611370
# std      332.045938
# min       40.000000
# 25%      200.000000
# 50%      300.000000
# 75%      450.000000
# max     5000.000000

# %%
dataset.drop(['Zomato URL', 'Address'], axis = 1, inplace=True)

# %%
dataset
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 12027        CK's Sandwiches            Porur
# 12028        CK's Sandwiches         Kolathur
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 1      ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# ...                                                  ...
# ...

# %%
dataset.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
dataset['Dining Rating'].value_counts()
# Out:
# None    5351
# 3.6      584
# 3.5      553
# 3.7      525
# 3.4      500
# 3.3      463
# 3.8      460
# 3.2      433
# 3.9      379
# 3.1      363
# 2.0      354
# 3.0      302
# 4.0      288
# 2.9      257
# 4.1      221
# 2.8      192
# 4.2      142
# 2.7      138
# 4.3      105
# 2.6       99
# 2.5       71
# 4.4       61
# 2.4       46
# 4.5       36
# 2.3       32
# 2.2       20
# 4.6       17
# 4.7       12
# 2.1       10
# 4.9        7
# 4.8        4
# 1.9        3
# 1.7        2
# 1.0        1
# 0.3        1
# Name: Dining Rating, dtype: int64

# %%
# Replacing the text values with '0' 
 
dataset['Dining Rating'].replace(to_replace=['None'], value='0', inplace=True)

# %%
dataset['Dining Rating'].value_counts()
# Out:
# 0      5351
# 3.6     584
# 3.5     553
# 3.7     525
# 3.4     500
# 3.3     463
# 3.8     460
# 3.2     433
# 3.9     379
# 3.1     363
# 2.0     354
# 3.0     302
# 4.0     288
# 2.9     257
# 4.1     221
# 2.8     192
# 4.2     142
# 2.7     138
# 4.3     105
# 2.6      99
# 2.5      71
# 4.4      61
# 2.4      46
# 4.5      36
# 2.3      32
# 2.2      20
# 4.6      17
# 4.7      12
# 2.1      10
# 4.9       7
# 4.8       4
# 1.9       3
# 1.7       2
# 1.0       1
# 0.3       1
# Name: Dining Rating, dtype: int64

# %%
 # Checking for text values in the column before converting it to numeric datatype 
 
dataset['Delivery Rating'].value_counts()
# Out:
# None    5851
# 3.9     1383
# 3.8      701
# 4.0      570
# 3.7      559
# 4.1      468
# 3.6      465
# 4.2      401
# 3.5      314
# 4.3      277
# 3.4      259
# 3.3      189
# 4.4      128
# 3.2       93
# 3.1       79
# 3.0       63
# 4.5       55
# 2.9       39
# 2.8       26
# 4.6       24
# 2.7       19
# 2.6       17
# 2.5        9
# 0.3        8
# 2.4        7
# 2.3        5
# 2.2        5
# 1.8        5
# 2.0        5
# 4.7        4
# 2.1        2
# 1.5        1
# 1.6        1
# Name: Delivery Rating, dtype: int64

# %%
# Replacing the text values with '0' 
 
dataset['Delivery Rating'].replace(to_replace=['None'], value='0', inplace=True)

# %%
# Changing Data Type of the numerical columns 
 
dataset['Dining Rating'] = dataset['Dining Rating'].astype('float64') 
dataset['Delivery Rating'] = dataset['Delivery Rating'].astype('float64')

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 10 columns):
# Name of Restaurant       12032 non-null object
# Location                 12032 non-null object
# Cuisine                  12032 non-null object
# Top Dishes               12032 non-null object
# Price for 2              12032 non-null float64
# Dining Rating            12032 non-null float64
# Dining Rating Count      12032 non-null object
# Delivery Rating          12032 non-null float64
# Delivery Rating Count    12032 non-null object
# Features                 12032 non-null object
# dtypes: float64(3), object(7)
# memory usage: 940.1+ KB

# %%
# Finding those restaurant whose has 0 Rating or Votes 
useless_data = (dataset['Dining Rating'] == 0.0) | (dataset['Delivery Rating'] == 0) 
dataset[useless_data]
# Out:
#              Name of Restaurant                        Location  \
# 6            Bai Veetu Kalyanam                        Navallur
# 15                Welcome Hotel                    Purasavakkam
# 18      Wire Room Bar & Kitchen  Phoenix Market City, Velachery
# 23                      BFF 2.0                        RA Puram
# 77     Al Dhareeq Beef Biriyani                     Kodambakkam
# ...                         ...                             ...
# 12027           CK's Sandwiches                           Porur
# 12028           CK's Sandwiches                        Kolathur
# 12029           CK's Sandwiches                 Anna Nagar East
# 12030           CK's Sandwiches                       Ramapuram
# 12031           CK's Sandwiches                  Sholinganallur
#
#                                             Cuisine  \
# 6                                       ['Biryani']
# 15      ['South Indian', ' Desserts', ' Beverages']
# ...

# %%
 # Checking the unique values in the column 
 
dataset['Dining Rating'].value_counts()
# Out:
# 0.0    5351
# 3.6     584
# 3.5     553
# 3.7     525
# 3.4     500
# 3.3     463
# 3.8     460
# 3.2     433
# 3.9     379
# 3.1     363
# 2.0     354
# 3.0     302
# 4.0     288
# 2.9     257
# 4.1     221
# 2.8     192
# 4.2     142
# 2.7     138
# 4.3     105
# 2.6      99
# 2.5      71
# 4.4      61
# 2.4      46
# 4.5      36
# 2.3      32
# 2.2      20
# 4.6      17
# 4.7      12
# 2.1      10
# 4.9       7
# 4.8       4
# 1.9       3
# 1.7       2
# 0.3       1
# 1.0       1
# Name: Dining Rating, dtype: int64

# %%
 ## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame 
## This permamnently remove the wrong data from the original dataframe 
 
dataset = dataset[~useless_data]

# %%
dataset['Dining Rating'].value_counts()
# Out:
# 3.7    387
# 3.6    377
# 3.5    359
# 3.8    334
# 3.4    324
# 3.9    301
# 3.3    294
# 3.2    262
# 3.1    236
# 4.0    222
# 3.0    192
# 4.1    166
# 2.9    161
# 2.8    120
# 2.0    111
# 4.2    105
# 4.3     87
# 2.7     78
# 2.6     56
# 2.5     44
# 4.4     41
# 2.4     26
# 4.5     26
# 2.3     18
# 2.2     12
# 4.6     11
# 4.7      9
# 4.9      7
# 2.1      6
# 1.9      3
# 4.8      3
# 1.7      2
# 0.3      1
# Name: Dining Rating, dtype: int64

# %%
dataset['Location'].value_counts()
# Out:
# Porur                                                       148
# Anna Nagar East                                             146
# Velachery                                                   145
# Ambattur                                                    124
# T. Nagar                                                    119
#                                                            ...
# RMZ Millenia Business Park, Old Mahabalipuram Road (OMR)      1
# Gokulam Park Sabari - OMR, Old Mahabalipuram Road             1
# Kipling, East Coast Road (ECR)                                1
# Somerset Greenways                                            1
# The King's Hotel, Egmore                                      1
# Name: Location, Length: 161, dtype: int64

# %%
# Finding all the duplicate rows 
 
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
 # Dropping all the duplicate rows 
 
dataset = dataset.drop_duplicates()

# %%
zomato_df = dataset.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                  ['Zinger Burger']        500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
#
# ...

# %%
# Splitting the column and storing it in temp_df dataframe  
 
zomato_df = dataset['Features'].str.split(",", n = 1, expand = True) 
zomato_df
# Out:
#                       0                                                  1
# 0      ['Home Delivery'                                  'Indoor Seating']
# 1      ['Home Delivery'   'Free Parking', 'Table booking recommended', ...
# 2      ['Home Delivery'                                  'Indoor Seating']
# 3      ['Home Delivery'   'Free Parking', 'Card Upon Delivery', 'Indoor...
# 4      ['Home Delivery'                                  'Indoor Seating']
# ...                 ...                                                ...
# 11666  ['Home Delivery'               'Vegetarian Only', 'Indoor Seating']
# 11667  ['Home Delivery'               'Vegetarian Only', 'Indoor Seating']
# 11736  ['Home Delivery'                                  'Indoor Seating']
# 11785  ['Home Delivery'                                  'Indoor Seating']
# 11794  ['Home Delivery'                                  'Indoor Seating']
#
# [4381 rows x 2 columns]

# %%
# Assigning the columns back to the raw_df dataframe
dataset['Delivery type'] = zomato_df[0] 
dataset['Chusion style'] = zomato_df[1] 
dataset.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                  ['Zinger Burger']        500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
#
# ...

# %%
dataset.isnull().sum()
# Out:
# Name of Restaurant        0
# Location                  0
# Cuisine                   0
# Top Dishes                0
# Price for 2               0
# Dining Rating             0
# Dining Rating Count       0
# Delivery Rating           0
# Delivery Rating Count     0
# Features                  0
# Delivery type             0
# Chusion style            14
# dtype: int64

# %%
dataset.fillna('NA', inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# Delivery type            0
# Chusion style            0
# dtype: int64

# %%
# Finding those restaurant whose has 0 Rating or Votes 
useless_data = (dataset['Dining Rating'] == 0.0) | (dataset['Delivery Rating'] == 0) 
dataset[useless_data]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features, Delivery type, Chusion style]
# Index: []

# %%
dataset.shape
# Out:
# (4381, 12)

# %%
zomato_df = dataset.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                  ['Zinger Burger']        500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
#
# ...

# %% [markdown]
# # Performing Exploratory Data Analysis
# Q1) How many restaurants are in Chennai for each type of cuisine?

# %%
fig = px.histogram(zomato_df, x='Cuisine', color='Cuisine',  
             title= 'No. of Restaurants by Cuisine Type',  
             labels={'Cuisine':'Cuisine Type'}) 
fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Chennai?

# %%
rating_type_df = zomato_df['Dining Rating'].value_counts().reset_index() 
rating_type_df.rename(columns={'index':'Dining Rating', 'Dining Rating':'COUNT OF RESTAURANTS'}, inplace=True) 
rating_type_df
# Out:
#     Dining Rating  COUNT OF RESTAURANTS
# 0             3.7                   387
# 1             3.6                   377
# 2             3.5                   359
# 3             3.8                   334
# 4             3.4                   324
# 5             3.9                   301
# 6             3.3                   294
# 7             3.2                   262
# 8             3.1                   236
# 9             4.0                   222
# 10            3.0                   192
# 11            4.1                   166
# 12            2.9                   161
# 13            2.8                   120
# 14            2.0                   111
# 15            4.2                   105
# 16            4.3                    87
# 17            2.7                    78
# 18            2.6                    56
# 19            2.5                    44
# 20            4.4                    41
# 21            2.4                    26
# ...

# %%
fig = px.pie(rating_type_df, names='Dining Rating', values='COUNT OF RESTAURANTS', color='Dining Rating',  
title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated with free parking Restaurant in Chennai?

# %%
free_Parking_df = zomato_df[zomato_df['Chusion style'].str.contains('Free Parking')] 
free_Parking_df.sort_values(by='Dining Rating',ascending=False).head(10)
# Out:
#                     Name of Restaurant         Location  \
# 155                  The Sandwich Shop    West Mambalam
# 184               Gossip Fusion Bistro         Kanathur
# 320                       Bombay Kulfi            Adyar
# 163   Momo Sa-Khang by Kailash Kitchen      Choolaimedu
# 9541                      Bombay Kulfi  Anna Nagar East
# 234                              Hamsa            Adyar
# 37                        Shree Mithai          Chetpet
# 9229                   Blind Ch3mistry        Teynampet
# 9363                       Flower Drum            Adyar
# 284                      Absolute Thai  Foodies Kitchen
#
#                                                 Cuisine  \
# 155            ['Sandwich', ' Fast Food', ' Beverages']
# 184   ['Italian', ' Continental', ' Burger', ' Sandw...
# 320                                       ['Ice Cream']
# 163                               ['Momos', ' Chinese']
# 9541                                      ['Ice Cream']
# ...

# %% [markdown]
# # Q4) What are the best restaurent in Chenai Kanathur?

# %%
Kanathur_df = zomato_df[zomato_df['Location'] == 'Kanathur'] 
Kanathur_df.sort_values(by='Dining Rating',ascending=False).head(2)
# Out:
#         Name of Restaurant  Location  \
# 184   Gossip Fusion Bistro  Kanathur
# 5205           Bristo Dive  Kanathur
#
#                                                 Cuisine  \
# 184   ['Italian', ' Continental', ' Burger', ' Sandw...
# 5205            ['Andhra', ' North Indian', ' Chinese']
#
#                                              Top Dishes  Price for 2  \
# 184   ['Tender Coconut Mousse', ' Iced Tea', ' Pasta...       1500.0
# 5205                                            Invalid        500.0
#
#       Dining Rating Dining Rating Count  Delivery Rating  \
# 184             4.9                 996              4.3
# 5205            3.2                   5              3.9
#
#      Delivery Rating Count                                           Features  \
# 184                    500  ['Breakfast', 'Home Delivery', 'Free Parking',...
# 5205                    93  ['Home Delivery', 'Table Reservation Not Requi...
#
# ...

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Chennai?

# %%
# Assuming restaurants having rating above 4.5 
 
highest_rated_df = zomato_df[zomato_df['Dining Rating'] >= 4.5] 
highest_rated_df
# Out:
#                       Name of Restaurant                             Location  \
# 24                        Eating Circles                             Alwarpet
# 37                          Shree Mithai                              Chetpet
# 50                           Andhikkadai                            Velachery
# 57                        Brownie Heaven                           Royapettah
# 59                                 Mezze                             Alwarpet
# 62    Amadora Gourmet Ice Cream & Sorbet                         Nungambakkam
# 67                         Pumpkin Tales                             Alwarpet
# 68          Sandy's Chocolate Laboratory                         Nungambakkam
# 70                          Little Italy                         Besant Nagar
# 75                       Fusilli Reasons                              Kilpauk
# 78                 Shri Rajasthani Dhaba                      Anna Nagar West
# ...

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Chennai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['Location', 'Cuisine'])['Price for 2'].mean().reset_index() 
highest_rated_price_df.head()
# Out:
#    Location                                            Cuisine  Price for 2
# 0     Adyar                               ['Chinese', ' Thai']        800.0
# 1     Adyar                                      ['Ice Cream']        200.0
# 2     Adyar  ['North Indian', ' Chettinad', ' Mughlai', ' D...       1800.0
# 3     Adyar                                   ['South Indian']        500.0
# 4  Alwarpet                         ['Desserts', ' Ice Cream']        350.0

# %%
fig = px.scatter(highest_rated_price_df, x="Location", y="Price for 2", color="Cuisine", symbol="Cuisine",  
           title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
 
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Breakfast Restaurant?

# %%
Breakfast_df = zomato_df[zomato_df['Delivery type'].str.contains('Breakfast')] 
Breakfast_df
# Out:
#              Name of Restaurant         Location  \
# 7                  Cafe Arabica  Anna Nagar East
# 9      Sangeetha Veg Restaurant         T. Nagar
# 10                   McDonald's        Velachery
# 14              Hotel Paramount          Kilpauk
# 21            Mami Tiffen Stall         Mylapore
# ...                         ...              ...
# 11500                 Mcrennett  Anna Nagar East
# 11502                 Mcrennett  Thousand Lights
# 11504                 Mcrennett            Porur
# 11505                 Mcrennett     Purasavakkam
# 11545        Anandhi Idly Kadai         Selaiyur
#
#                                                  Cuisine  \
# 7                                 ['Cafe', ' Fast Food']
# 9      ['South Indian', ' North Indian', ' Chinese', ...
# 10                              ['Burger', ' Fast Food']
# 14     ['North Indian', ' Chinese', ' Seafood', ' Sou...
# 21     ['South Indian', ' North Indian', ' Chinese', ...
# ...

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index() 
price_rating_df
# Out:
#                                                 Cuisine  Dining Rating  \
# 0     ['American', ' Continental', ' European', ' It...            3.9
# 1     ['American', ' Continental', ' Italian', ' Nor...            4.1
# 2                          ['American', ' Continental']            4.1
# 3                            ['American', ' Fast Food']            2.7
# 4                            ['American', ' Fast Food']            3.9
# ...                                                 ...            ...
# 2891                              ['Tibetan', ' Momos']            3.1
# 2892                              ['Tibetan', ' Momos']            3.4
# 2893                              ['Tibetan', ' Momos']            3.5
# 2894                              ['Tibetan', ' Momos']            3.6
# 2895                              ['Turkish', ' Kebab']            4.3
#
#       Price for 2
# 0           700.0
# 1           800.0
# 2          1600.0
# 3           300.0
# ...

# %%
 fig = px.line(price_rating_df, y="Price for 2", x="Dining Rating",color='Cuisine') 
 fig.show()

# %% [markdown]
# # Q9) Find the list of Affordable Restaurants?
# The criteria for Affordable Restaurants would be:
# 1) Low Price 2) High Rated
#  First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
#  Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
#  restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['Price for 2'].max() 
one_fourth_price = max_price/4 
one_fourth_price
# Out:
# 750.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
 
aff_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location']] 
aff_rest_df = aff_rest_df[aff_rest_df['Price for 2'] <= 750] 
aff_rest_df.sort_values(by='Price for 2', inplace=True) 
aff_rest_df
# Out:
#                Name of Restaurant  Price for 2  \
# 5547       Mylapore Filter Coffee        100.0
# 2151                     Cane 4 U        100.0
# 2511               Rose Milk Raja        100.0
# 1326   Madurai Famous Jigarthanda        100.0
# 108                  Rayar's Mess        100.0
# ...                           ...          ...
# 10071             Long Live Pizza        750.0
# 9568             Ponnusamy Hotels        750.0
# 9571             Ponnusamy Hotels        750.0
# 10074             Long Live Pizza        750.0
# 9627                   Kaaraikudi        750.0
#
#                                                  Cuisine  \
# 5547                       ['Street Food', ' Beverages']
# 2151                                       ['Beverages']
# 2511                                       ['Beverages']
# 1326                         ['Beverages', ' Ice Cream']
# 108                                     ['South Indian']
# ...

# %%
 # Finding the highest rated list of restaurants 
 
highrate_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location','Dining Rating']] 
highrate_rest_df = highrate_rest_df[highrate_rest_df['Dining Rating'] >= 4.5] 
highrate_rest_df.sort_values(by='Price for 2', inplace=True) 
highrate_rest_df
# Out:
#                       Name of Restaurant  Price for 2  \
# 108                         Rayar's Mess        100.0
# 178                  Royal Sandwich Shop        150.0
# 9541                        Bombay Kulfi        200.0
# 320                         Bombay Kulfi        200.0
# 50                           Andhikkadai        200.0
# 24                        Eating Circles        250.0
# 37                          Shree Mithai        300.0
# 270                                   ID        300.0
# 155                    The Sandwich Shop        300.0
# 209                          Cream Stone        350.0
# 9367                         Cream Stone        350.0
# 92             Fruit Shop On Greams Road        350.0
# 57                        Brownie Heaven        350.0
# 163     Momo Sa-Khang by Kailash Kitchen        350.0
# 255                         Krispy Kreme        400.0
# 471   Shmoozie's Hand-Crafted Ice Creams        400.0
# ...

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['Name of Restaurant', 'Location']) 
highrate_aff_df = highrate_aff_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location', 'Cuisine_x']] 
highrate_aff_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'PRICE_x':'Price for 2', 'Cuisine_x':'Cuisine',  
                                'Location':'Location', 'CUSINE TYPE_x':'Cuisine'},inplace=True)

# %%
 # Affordable Restaurants with low price and high rating  
 
highrate_aff_df
# Out:
#                     Name of Restaurant  Price for 2_x  \
# 0                         Rayar's Mess          100.0
# 1                  Royal Sandwich Shop          150.0
# 2                  Royal Sandwich Shop          150.0
# 3                  Royal Sandwich Shop          150.0
# 4                          Andhikkadai          200.0
# 5                         Bombay Kulfi          200.0
# 6                         Bombay Kulfi          200.0
# 7                       Eating Circles          250.0
# 8                         Shree Mithai          300.0
# 9                                   ID          300.0
# 10                   The Sandwich Shop          300.0
# 11                         Cream Stone          350.0
# 12    Momo Sa-Khang by Kailash Kitchen          350.0
# 13                         Cream Stone          350.0
# 14                      Brownie Heaven          350.0
# 15           Fruit Shop On Greams Road          350.0
# ...

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# The criteria for most Reliable Restaurants would be:
#
# 1)Low Price 2) High Rated 3)Large Dining Rating Count
#   will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['Dining Rating Count'].mean() 
mean_votes
# Out:
# inf
